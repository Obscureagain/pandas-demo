# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',79)
pd.set_option('display.max_colwidth', None)
#pd.reset_option('display.max_colwidth')
pd.set_option('display.max_rows',79)
pd.set_option('float_format', '{:f}'.format)

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
df.head()
# Out:
#                                                                                MainBranch  \
# ResponseId
# 1                                                                           None of these
# 2                                                          I am a developer by profession
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 4                                                          I am a developer by profession
# 5                                                          I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# ...

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
sdf_html = schema_df.loc[schema_df['qid'].isin(['QID16', 'QID1', 'QID190', 'QID191', 'QID295', 'QID121'])].index
schema_df.drop(sdf_html, inplace = True)
schema_df
# Out:
#                          qid  \
# qname
# MetaInfo               QID12
# MainBranch              QID2
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# CompFreq               QID52
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# OpSys                  QID71
# VersionControlSystem  QID283
# VCInteraction         QID284
# ...

# %%
df.groupby('LearnCode')['LearnCode'].value_counts().sort_values(ascending=False)
# Out:
# LearnCode                                                                                                                                                               LearnCode
# School (i.e., University, College, etc)                                                                                                                                 School (i.e., University, College, etc)                                                                                                                                   3669
# Other online resources (e.g., videos, blogs, forum)                                                                                                                     Other online resources (e.g., videos, blogs, forum)                                                                                                                       3292
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.iloc[[0,1],3].reset_index()
# Out:
#    index    RemoteWork
# 0      0           NaN
# 1      1  Fully remote

# %%
df['RemoteWork'].value_counts()
# Out:
# Fully remote                            25341
# Hybrid (some remote, some in-person)    25021
# Full in-person                           8596
# Name: RemoteWork, dtype: int64

# %%
df['RemoteWork'].value_counts(normalize=True)
# Out:
# Fully remote                           0.429814
# Hybrid (some remote, some in-person)   0.424387
# Full in-person                         0.145799
# Name: RemoteWork, dtype: float64

# %%
#Women RemoteWork
df.loc[(df['Gender']=='Woman')]['RemoteWork'].value_counts(normalize=True)
# Out:
# Fully remote                           0.453488
# Hybrid (some remote, some in-person)   0.404433
# Full in-person                         0.142078
# Name: RemoteWork, dtype: float64

# %%
#Not women RemoteWork
df.loc[~(df['Gender']=='Woman')]['RemoteWork'].value_counts(normalize=True)
# Out:
# Fully remote                           0.428655
# Hybrid (some remote, some in-person)   0.425364
# Full in-person                         0.145981
# Name: RemoteWork, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
df.loc[0:4,'RemoteWork':'YearsCode']
# Out:
#                              RemoteWork  \
# 0                                   NaN
# 1                          Fully remote
# 2  Hybrid (some remote, some in-person)
# 3                          Fully remote
# 4  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
# ...

# %%
schema_df.loc['Knowledge_1']
# Out:
# qid                                                                  QID289
# question      I have interactions with people outside of my immediate team.
# force_resp                                                              NaN
# type                                                                     MC
# selector                                                               MAVR
# Name: Knowledge_1, dtype: object

# %%
df['Knowledge_1'].value_counts()
# Out:
# Agree                         17527
# Strongly agree                12188
# Neither agree nor disagree     3186
# Disagree                       2121
# Strongly disagree               782
# Name: Knowledge_1, dtype: int64

# %%
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# Accessibility         QID124
# Age                   QID127
# Blockchain            QID305
# BuyNewTool            QID279
# CodingActivities      QID297
# CompFreq               QID52
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Ethnicity             QID126
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Gender                QID122
# ICorPM                QID287
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# Knowledge_5           QID289
# Knowledge_6           QID289
# Knowledge_7           QID289
# Language              QID233
# LearnCode             QID276
# ...

# %%
filt = (df['Gender'] == 'Woman')
df[filt]
# Out:
#                                 MainBranch  \
# ResponseId
# 9           I am a developer by profession
# 10          I am a developer by profession
# 14          I am a developer by profession
# 18          I am a developer by profession
# 47             I code primarily as a hobby
# ...                                    ...
# 73215       I am a developer by profession
# 73217       I am a developer by profession
# 73233       I am a developer by profession
# 73239       I am a developer by profession
# 73240       I am a developer by profession
#
#                                                       Employment  \
# ResponseId
# 9                                            Employed, full-time
# 10          Independent contractor, freelancer, or self-employed
# 14                                           Employed, part-time
# 18                                           Employed, full-time
# 47                                            Student, full-time
# ...

# %%
df[filt]['ConvertedCompYearly'].describe()
# Out:
# count       1711.000000
# mean      154148.132086
# std      1151975.215673
# min            1.000000
# 25%        31996.500000
# 50%        63500.000000
# 75%       112537.500000
# max     44790396.000000
# Name: ConvertedCompYearly, dtype: float64

# %%
df[filt & (df['ConvertedCompYearly']==44790396)]
# Out:
#                                 MainBranch           Employment  \
# ResponseId
# 202         I am a developer by profession  Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 202         Hybrid (some remote, some in-person)
#
#                           CodingActivities  \
# ResponseId
# 202         Hobby;Bootstrapping a business
#
#                                                  EdLevel  \
# ResponseId
# 202         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                                                                                                                   LearnCode  \
# ResponseId
# 202         Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification
#
# ...

# %%
df[filt & (df['ConvertedCompYearly']==df[filt]['ConvertedCompYearly'].max())]
# Out:
#                                 MainBranch           Employment  \
# ResponseId
# 202         I am a developer by profession  Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 202         Hybrid (some remote, some in-person)
#
#                           CodingActivities  \
# ResponseId
# 202         Hobby;Bootstrapping a business
#
#                                                  EdLevel  \
# ResponseId
# 202         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                                                                                                                   LearnCode  \
# ResponseId
# 202         Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification
#
# ...

# %%
df[df['ConvertedCompYearly']==df[filt]['ConvertedCompYearly'].max()]
# Out:
#                                 MainBranch           Employment  \
# ResponseId
# 202         I am a developer by profession  Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 202         Hybrid (some remote, some in-person)
#
#                           CodingActivities  \
# ResponseId
# 202         Hobby;Bootstrapping a business
#
#                                                  EdLevel  \
# ResponseId
# 202         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                                                                                                                   LearnCode  \
# ResponseId
# 202         Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification
#
# ...

# %%
high_salary = (df['ConvertedCompYearly']>85000)

# %%
df.loc[high_salary, ['Country','LanguageHaveWorkedWith', 'ConvertedCompYearly']]
# Out:
#                                                          Country  \
# ResponseId
# 4                                                         Israel
# 12                                      United States of America
# 15                                      United States of America
# 18                                                       Austria
# 23                                                        Canada
# ...                                                          ...
# 73103       United Kingdom of Great Britain and Northern Ireland
# 73106                                   United States of America
# 73112                                   United States of America
# 73114                                   United States of America
# 73117                                   United States of America
#
#                                                                     LanguageHaveWorkedWith  \
# ResponseId
# ...

# %%
countries = ['United States', 'United Kindom', 'Germany', 'Canada', 'India']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, ['Country','LanguageHaveWorkedWith', 'ConvertedCompYearly']]
# Out:
#             Country  \
# ResponseId
# 2            Canada
# 6           Germany
# 7             India
# 8             India
# 23           Canada
# ...             ...
# 73256         India
# 73258         India
# 73259         India
# 73263       Germany
# 73268        Canada
#
#                                                   LanguageHaveWorkedWith  \
# ResponseId
# 2                                                  JavaScript;TypeScript
# 6                                                                C++;Lua
# 7                          C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 8                                     C;C++;HTML/CSS;Java;JavaScript;SQL
# 23                                                     C#;SQL;TypeScript
# ...                                                                  ...
# 73256       Bash/Shell;C#;HTML/CSS;JavaScript;Perl;PowerShell;TypeScript
# 73258                                                       C;Python;SQL
# ...

# %%
python_filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)
df.loc[python_filt, ['LanguageHaveWorkedWith', 'ConvertedCompYearly']]
# Out:
#                                                LanguageHaveWorkedWith  \
# ResponseId
# 3                                   C#;C++;HTML/CSS;JavaScript;Python
# 7                       C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 12                  C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 15                        HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 17                                               C#;Java;PHP;Python;R
# ...                                                               ...
# 73258                                                    C;Python;SQL
# 73262       Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 73264            Bash/Shell;Dart;JavaScript;PHP;Python;SQL;TypeScript
# 73265                       Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73266                              HTML/CSS;JavaScript;PHP;Python;SQL
#
#             ConvertedCompYearly
# ResponseId
# 3                  40205.000000
# 7                           NaN
# ...

# %%
#Use to rename certain columns; must add inplace=True to actually change df
df.rename(columns={'LanguageHaveWorkedWith': 'Languages', 'ConvertedCompYearly': 'Salary'})
# Out:
#                                                                                MainBranch  \
# ResponseId
# 1                                                                           None of these
# 2                                                          I am a developer by profession
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 4                                                          I am a developer by profession
# 5                                                          I am a developer by profession
# ...                                                                                   ...
# 73264                                                      I am a developer by profession
# 73265                                                      I am a developer by profession
# 73266       I am not primarily a developer, but I write code sometimes as part of my work
# ...

# %%
df['LanguageHaveWorkedWith'].str.split(';', expand=True)
# Out:
#                     0           1           2           3       4   \
# ResponseId
# 1                  NaN         NaN         NaN         NaN     NaN
# 2           JavaScript  TypeScript        None        None    None
# 3                   C#         C++    HTML/CSS  JavaScript  Python
# 4                   C#  JavaScript         SQL  TypeScript    None
# 5                   C#    HTML/CSS  JavaScript         SQL   Swift
# ...                ...         ...         ...         ...     ...
# 73264       Bash/Shell        Dart  JavaScript         PHP  Python
# 73265       Bash/Shell    HTML/CSS  JavaScript      Python     SQL
# 73266         HTML/CSS  JavaScript         PHP      Python     SQL
# 73267               C#      Delphi         VBA        None    None
# 73268               C#  JavaScript         Lua  PowerShell     SQL
#
#                     5           6     7     8     9     10    11    12    13  \
# ResponseId
# ...

# %%
df['ConvertedCompYearly'].nlargest(10)
# Out:
# ResponseId
# 40305   50000000.000000
# 202     44790396.000000
# 62027   35000000.000000
# 70523   32500000.000000
# 61044   28853768.000000
# 18923   22500000.000000
# 62224   22500000.000000
# 66496   18000000.000000
# 1291    15000000.000000
# 24164   15000000.000000
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nlargest(10,'ConvertedCompYearly')
# Out:
#                                 MainBranch  \
# ResponseId
# 40305       I am a developer by profession
# 202         I am a developer by profession
# 62027       I am a developer by profession
# 70523       I am a developer by profession
# 61044       I am a developer by profession
# 18923       I am a developer by profession
# 62224       I am a developer by profession
# 66496       I am a developer by profession
# 1291        I am a developer by profession
# 24164       I am a developer by profession
#
#                                                       Employment  \
# ResponseId
# 40305       Independent contractor, freelancer, or self-employed
# 202                                          Employed, full-time
# 62027                                        Employed, full-time
# 70523       Independent contractor, freelancer, or self-employed
# 61044                                        I prefer not to say
# 18923                                        Employed, full-time
# ...

# %%
df.median(numeric_only=True)
# Out:
# CompTotal                   77500.000000
# VCHostingPersonal use                NaN
# VCHostingProfessional use            NaN
# WorkExp                         8.000000
# ConvertedCompYearly         67845.000000
# dtype: float64

# %%
df.describe()
# Out:
#                                                              CompTotal  \
# count                                                     38422.000000
# mean      23424340221747959297504942608856691548764873498296320.000000
# std     4591478187815219735465859539580935570737502995792003072.000000
# min                                                           0.000000
# 25%                                                       30000.000000
# 50%                                                       77500.000000
# 75%                                                      154000.000000
# max   900000000000000060934480090350342481100335261807995256832.000000
#
#        VCHostingPersonal use  VCHostingProfessional use      WorkExp  \
# count               0.000000                   0.000000 36769.000000
# mean                     NaN                        NaN    10.242378
# std                      NaN                        NaN     8.706850
# ...

# %%
schema_df.head()
# Out:
#                      qid  \
# qname
# MetaInfo           QID12
# MainBranch          QID2
# Employment        QID296
# RemoteWork        QID308
# CodingActivities  QID297
#
#                                                                                                                                    question  \
# qname
# MetaInfo                                                                                                                  Browser Meta Info
# MainBranch        Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code." <b>*</b>
# Employment                                                            Which of the following best describes your current employment status?
# RemoteWork                                                                                Which best describes your current work situation?
# ...

# %%
schema_df['question'].str.contains('media').value_counts()
# Out:
# False    71
# True      3
# Name: question, dtype: int64

# %%
#find question that contains specific word
schema_df['question'][schema_df['question'].str.contains('manager') == True].reset_index()
# Out:
#     qname                                               question
# 0  ICorPM  Are you an independent contributor or people manager?

# %%
df['ICorPM'].value_counts()
# Out:
# Independent contributor    30592
# People manager              5691
# Name: ICorPM, dtype: int64

# %%
df['ICorPM'].value_counts(normalize=True)
# Out:
# Independent contributor   0.843150
# People manager            0.156850
# Name: ICorPM, dtype: float64

# %%
df[['ICorPM','ConvertedCompYearly']]

# %%
df.groupby('ICorPM')['ConvertedCompYearly'].median()
# Out:
# ICorPM
# Independent contributor   63986.000000
# People manager            76794.000000
# Name: ConvertedCompYearly, dtype: float64

# %%
df.groupby('ICorPM')['ConvertedCompYearly'].mean()
# Out:
# ICorPM
# Independent contributor   158669.408406
# People manager            170479.387210
# Name: ConvertedCompYearly, dtype: float64

# %%
df.groupby('ICorPM')['ConvertedCompYearly'].max()
# Out:
# ICorPM
# Independent contributor   50000000.000000
# People manager            10000000.000000
# Name: ConvertedCompYearly, dtype: float64

# %%
df.groupby('ICorPM')['ConvertedCompYearly'].min()
# Out:
# ICorPM
# Independent contributor   1.000000
# People manager            1.000000
# Name: ConvertedCompYearly, dtype: float64

# %%
#find question that contains specific word
schema_df['question'][schema_df['question'].str.contains('') == True].reset_index()
# Out:
#                    qname                                           question
# 0               MetaInfo                                  Browser Meta Info
# 1             MainBranch  Which of the following options best describes ...
# 2             Employment  Which of the following best describes your cur...
# 3             RemoteWork  Which best describes your current work situation?
# 4       CodingActivities  Which of the following best describes the code...
# 5                EdLevel  Which of the following best describes the high...
# 6              LearnCode  How did you learn to code? Select all that apply.
# 7        LearnCodeOnline  What online resources do you use to learn to c...
# 8   LearnCodeCoursesCert  What online courses or certifications do you u...
# 9              YearsCode  Including any education, how many years have y...
# 10          YearsCodePro  NOT including education, how many years have y...
# ...

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Colombia')
# Out:
#                                 MainBranch  \
# ResponseId
# 1267        I am a developer by profession
# 1430        I am a developer by profession
# 2377        I am a developer by profession
# 2699                 I am learning to code
# 2937        I am a developer by profession
# ...                                    ...
# 72537       I am a developer by profession
# 72622       I am a developer by profession
# 72821       I am a developer by profession
# 72835       I am a developer by profession
# 72936       I am a developer by profession
#
#                                                                           Employment  \
# ResponseId
# 1267                                          Student, full-time;Employed, part-time
# 1430                                          Employed, full-time;Student, part-time
# 2377                            Independent contractor, freelancer, or self-employed
# ...

# %%
ountry_grp['LanguageHaveWorkedWith'].value_counts().loc['Colombia']
# Out:
# LanguageHaveWorkedWith
# HTML/CSS;JavaScript;TypeScript           11
# HTML/CSS;JavaScript                       6
# HTML/CSS;JavaScript;Python;SQL            6
# HTML/CSS;JavaScript;Python;TypeScript     6
# JavaScript;TypeScript                     6
#                                          ..
# Objective-C;Swift                         1
# PHP                                       1
# Ruby                                      1
# SQL                                       1
# Scala                                     1
# Name: LanguageHaveWorkedWith, Length: 246, dtype: int64

# %%
country_grp['ConvertedCompYearly'].median().sort_values(ascending=False)
# Out:
# Country
# Monaco                     5000000.000000
# Haiti                      1560600.000000
# United States of America    145000.000000
# Israel                      128238.000000
# Barbados                    125001.000000
#                                 ...
# Saint Kitts and Nevis                 NaN
# San Marino                            NaN
# Sierra Leone                          NaN
# Solomon Islands                       NaN
# Swaziland                             NaN
# Name: ConvertedCompYearly, Length: 180, dtype: float64

# %%
country_grp['ConvertedCompYearly'].agg(['median','mean','min', 'max']).sort_values('median', ascending=False).head(20)
# Out:
#                                                              median  \
# Country
# Monaco                                               5000000.000000
# Haiti                                                1560600.000000
# United States of America                              145000.000000
# Israel                                                128238.000000
# Barbados                                              125001.000000
# Lao People's Democratic Republic                      120000.000000
# Switzerland                                           113761.000000
# Ireland                                                95979.000000
# Australia                                              93772.000000
# Canada                                                 93701.000000
# Iceland                                                91920.000000
# Denmark                                                89472.000000
# New Zealand                                            83633.000000
# ...

# %%
filt = df['Country'] == 'Colombia'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 161

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum()/x.count())
# Out:
# Country
# Afghanistan                            0.390625
# Albania                                0.339286
# Algeria                                0.527778
# Andorra                                0.266667
# Angola                                 0.272727
#                                          ...
# Venezuela, Bolivarian Republic of...   0.440678
# Viet Nam                               0.447368
# Yemen                                  0.285714
# Zambia                                 0.352941
# Zimbabwe                               0.392857
# Name: LanguageHaveWorkedWith, Length: 180, dtype: float64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
pct_python_users = country_uses_python / country_respondents
pct_python_users
# Out:
# Afghanistan                            0.362319
# Albania                                0.322034
# Algeria                                0.527778
# Andorra                                0.266667
# Angola                                 0.250000
#                                          ...
# Venezuela, Bolivarian Republic of...   0.436975
# Viet Nam                               0.429022
# Yemen                                  0.285714
# Zambia                                 0.300000
# Zimbabwe                               0.366667
# Length: 180, dtype: float64

# %%
python_df = pd.concat([country_uses_python, country_respondents], axis='columns', sort=False)
python_df
# Out:
#                                       LanguageHaveWorkedWith  Country
# Afghanistan                                               25       69
# Albania                                                   19       59
# Algeria                                                   19       36
# Andorra                                                    4       15
# Angola                                                     3       12
# ...                                                      ...      ...
# Venezuela, Bolivarian Republic of...                      52      119
# Viet Nam                                                 136      317
# Yemen                                                      4       14
# Zambia                                                     6       20
# Zimbabwe                                                  11       30
#
# [180 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageHaveWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                                       NumKnowsPython  NumRespondents
# Afghanistan                                       25              69
# Albania                                           19              59
# Algeria                                           19              36
# Andorra                                            4              15
# Angola                                             3              12
# ...                                              ...             ...
# Venezuela, Bolivarian Republic of...              52             119
# Viet Nam                                         136             317
# Yemen                                              4              14
# Zambia                                             6              20
# Zimbabwe                                          11              30
#
# [180 rows x 2 columns]

# %%
python_df['PctKnowsPython']=(python_df['NumKnowsPython']/python_df['NumRespondents'])*100

# %%
python_df
# Out:
#                                       NumKnowsPython  NumRespondents  \
# Afghanistan                                       25              69
# Albania                                           19              59
# Algeria                                           19              36
# Andorra                                            4              15
# Angola                                             3              12
# ...                                              ...             ...
# Venezuela, Bolivarian Republic of...              52             119
# Viet Nam                                         136             317
# Yemen                                              4              14
# Zambia                                             6              20
# Zimbabwe                                          11              30
#
#                                       PctKnowsPython
# Afghanistan                                36.231884
# ...

# %%
python_df['PctKnowsPython'].mean()
# Out:
# 45.07091511373658

# %%
python_df.sort_values(by='NumRespondents', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                                       NumKnowsPython  \
# United States of America                                        7017
# India                                                           3081
# Germany                                                         2674
# United Kingdom of Great Britain and Northern Ireland            2082
# Canada                                                          1272
# France                                                          1204
# Brazil                                                           873
# Poland                                                           810
# Netherlands                                                      714
# Spain                                                            698
# Italy                                                            699
# Australia                                                        705
# Russian Federation                                               590
# ...
